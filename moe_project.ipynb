# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushboo-Dar/Mixture-Of-Experts/blob/main/moe_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/Khushboo-Dar/Mixture-Of-Experts.git
# Out:
# Cloning into 'Mixture-Of-Experts'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 96 (delta 9), reused 96 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (96/96), 23.18 MiB | 15.26 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# !pip install --upgrade pandas
# !pip install pymatgen
# !pip install --upgrade pymatgen --quiet
# !pip install --upgrade numpy pandas torch
# !python -c "import pymatgen; print(pymatgen.__version__)"
# !pip install "pymatgen==2022.0.17"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 94.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...

# %%
exit()

# %%
# !pip install --upgrade pip setuptools wheel
# !apt-get install -y python3-dev libopenblas-dev liblapack-dev libfftw3-dev gfortran
# !pip install pymatgen
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gfortran is already the newest version (4:11.2.0-1ubuntu1).
# liblapack-dev is already the newest version (3.10.0-2ubuntu1).
# libopenblas-dev is already the newest version (0.3.20+ds-1).
# python3-dev is already the newest version (3.10.6-1~22.04.1).
# python3-dev set to manually installed.
# The following additional packages will be installed:
#   libfftw3-bin libfftw3-double3 libfftw3-long3 libfftw3-quad3 libfftw3-single3
# Suggested packages:
#   libfftw3-doc
# The following NEW packages will be installed:
#   libfftw3-bin libfftw3-dev libfftw3-double3 libfftw3-long3 libfftw3-quad3 libfftw3-single3
# 0 upgraded, 6 newly installed, 0 to remove and 18 not upgraded.
# Need to get 3,884 kB/4,654 kB of archives.
# After this operation, 24.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-long3 amd64 3.3.8-2ubuntu8 [335 kB]
# ...

# %%
# !pip install --upgrade pymatgen
import os
os._exit(00)

# %%
#run this first
# First, check the current Python version
# !python --version  # Ensure it's 3.11, or any other version that might be conflicting.

# Install Python 3.8 environment
# !sudo apt-get install python3.8
# !pip install torch==1.10.1
# !pip install pymatgen==2022.3.29
# !pip install numpy==1.21.2 scipy==1.7.3 matplotlib==3.4.3 pandas==1.3.3
# Out:
# Python 3.11.11
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.8-minimal libpython3.8-stdlib python3.8-minimal
# Suggested packages:
#   python3.8-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.8-minimal libpython3.8-stdlib python3.8 python3.8-minimal
# 0 upgraded, 4 newly installed, 0 to remove and 18 not upgraded.
# Need to get 5,076 kB of archives.
# After this operation, 18.8 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.8-minimal amd64 3.8.20-1+jammy1 [796 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8-minimal amd64 3.8.20-1+jammy1 [2,023 kB]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.8-stdlib amd64 3.8.20-1+jammy1 [1,817 kB]
# ...

# %%
#run this second
# !pip uninstall numpy -y

# !pip install numpy==1.23.5
# !pip show numpy
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 86.1 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.34.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# xarray 2025.1.1 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.23.5 which is incompatible.
# scikit-image 0.25.1 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# pymc 5.19.1 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
# !cd drive/MyDrive/MoE-main// && python main.py --option pairwise_TL --dataset_name expt_eform --extractor_name mp_eform
# Out:
# ------ seed 0 -------
# dataset: expt_eform
# num layers learned from scratch: 3
# layer to extract from: conv
# seed: 0
# num_layers_to_unfreeze: 1
# extractor name: mp_eform
# option: pairwise_TL
# use_all_extractors: False
# optim: Adam
# UNFROZE backbone.convs[-1]
# best val mae / stl val mae: 1.177067631665842
# best val mae / stl val mae: 1.177067631665842
# Test MAE: 0.12153038382530212
# ------ seed 1 -------
# dataset: expt_eform
# num layers learned from scratch: 3
# layer to extract from: conv
# seed: 1
# num_layers_to_unfreeze: 1
# extractor name: mp_eform
# option: pairwise_TL
# use_all_extractors: False
# optim: Adam
# UNFROZE backbone.convs[-1]
# best val mae / stl val mae: 1.021698371325409
# best val mae / stl val mae: 1.021698371325409
# Test MAE: 0.115364208817482
# ------ seed 2 -------
# dataset: expt_eform
# num layers learned from scratch: 3
# layer to extract from: conv
# seed: 2
# num_layers_to_unfreeze: 1
# extractor name: mp_eform
# option: pairwise_TL
# ...

# %%
# !cd drive/MyDrive/MoE-main// && python main.py --option pairwise_TL --dataset_name expt_eform --extractor_name jarvis_dft_2d_eform
# Out:
# ------ seed 0 -------
# dataset: expt_eform
# num layers learned from scratch: 3
# layer to extract from: conv
# seed: 0
# num_layers_to_unfreeze: 1
# extractor name: jarvis_dft_2d_eform
# option: pairwise_TL
# use_all_extractors: False
# optim: Adam
# /content/drive/MyDrive/MoE-main/moe/model.py:51: UserWarning: checkpoint_path is None. Learning a backbone from scratch.
#   warnings.warn('checkpoint_path is None. Learning a backbone from '
# UNFROZE backbone.convs[-1]
# best val mae / stl val mae: 2.5400156790849366
# best val mae / stl val mae: 2.5400156790849366
# Test MAE: 0.3163246214389801
# ------ seed 1 -------
# dataset: expt_eform
# num layers learned from scratch: 3
# layer to extract from: conv
# seed: 1
# num_layers_to_unfreeze: 1
# extractor name: jarvis_dft_2d_eform
# option: pairwise_TL
# use_all_extractors: False
# optim: Adam
# /content/drive/MyDrive/MoE-main/moe/model.py:51: UserWarning: checkpoint_path is None. Learning a backbone from scratch.
# ...

# %%
# !cd drive/MyDrive/MoE-main// && python main.py --option pairwise_TL --dataset_name mp_poly_electronic --extractor_name mp_eps_electronic
# Out:
# ------ seed 0 -------
# dataset: mp_poly_electronic
# num layers learned from scratch: 3
# layer to extract from: conv
# seed: 0
# num_layers_to_unfreeze: 1
# extractor name: mp_eps_electronic
# option: pairwise_TL
# use_all_extractors: False
# optim: Adam
# /content/drive/MyDrive/MoE-main/moe/model.py:51: UserWarning: checkpoint_path is None. Learning a backbone from scratch.
#   warnings.warn('checkpoint_path is None. Learning a backbone from '
# UNFROZE backbone.convs[-1]
# best val mae / stl val mae: 1.0527830463453915
# best val mae / stl val mae: 1.0527830463453915
# ...

# %%
# !cd drive/MyDrive/MoE-main// && python main.py --option pairwise_TL --dataset_name expt_bandgap --extractor_name jarvis_dft_2d_gap_opt
# Out:
# ------ seed 0 -------
# dataset: expt_bandgap
# num layers learned from scratch: 3
# layer to extract from: conv
# seed: 0
# num_layers_to_unfreeze: 1
# extractor name: jarvis_dft_2d_gap_opt
# option: pairwise_TL
# use_all_extractors: False
# optim: Adam
# /content/drive/MyDrive/MoE-main/moe/model.py:51: UserWarning: checkpoint_path is None. Learning a backbone from scratch.
#   warnings.warn('checkpoint_path is None. Learning a backbone from '
# UNFROZE backbone.convs[-1]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/MoE-main/main.py", line 526, in <module>
#     test_mae, normalized_val_mae = main(
#                                    ^^^^^
#   File "/content/drive/MyDrive/MoE-main/main.py", line 300, in main
#     train(structures, labels, model, cuda, option, normalizer,
#   File "/content/drive/MyDrive/MoE-main/main.py", line 423, in train
#     features = ensembled_backbone(structures)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !cd drive/MyDrive/MoE-main// && python main.py --option pairwise_TL --dataset_name mp_elastic_anisotropy --extractor_name piezoelectric_tensor
# Out:
# ------ seed 0 -------
# dataset: mp_elastic_anisotropy
# num layers learned from scratch: 3
# layer to extract from: conv
# seed: 0
# num_layers_to_unfreeze: 1
# extractor name: piezoelectric_tensor
# option: pairwise_TL
# use_all_extractors: False
# optim: Adam
# /content/drive/MyDrive/MoE-main/moe/model.py:51: UserWarning: checkpoint_path is None. Learning a backbone from scratch.
#   warnings.warn('checkpoint_path is None. Learning a backbone from '
# UNFROZE backbone.convs[-1]
# best val mae / stl val mae: 0.9630809721001893
# best val mae / stl val mae: 0.9630809721001893
# ...

# %%
# !cd drive/MyDrive/MoE-main// && python main.py --dataset_name expt_eform --option add_k --use_all_extractors --k_extractor_gating 4
# Out:
# ------ seed 0 -------
# dataset: expt_eform
# num layers learned from scratch: 3
# layer to extract from: conv
# seed: 0
# num_layers_to_unfreeze: 1
# extractor name: None
# option: add_k
# use_all_extractors: True
# optim: Adam
# k extractor gating: 4
# n_pseudo_attn_heads: 1
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
# UNFROZE backbone.convs[-1]
